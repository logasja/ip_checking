# %%
import pandas as pd

# %%
df = pd.read_csv('data_export2.csv')
df.head()
# Out:
#              StartDate              EndDate      Status       IPAddress  \
# 0  2022-12-06 14:06:19  2022-12-06 14:30:59  IP Address    24.56.247.88
# 1  2022-12-08 14:49:19  2022-12-08 14:49:28  IP Address     128.61.73.2
# 2  2022-12-02 21:55:51  2022-12-08 15:05:45  IP Address  216.110.195.70
# 3  2022-12-23 13:11:30  2022-12-23 13:44:40  IP Address   64.251.50.109
# 4  2023-01-25 13:11:56  2023-01-26 14:19:49  IP Address   128.61.19.112
#
#    Progress  Duration (in seconds)  Finished         RecordedDate  \
# 0       100                   1479      True  2022-12-06 14:30:59
# 1        25                      8     False  2022-12-15 14:49:35
# 2        75                 493794     False  2022-12-15 15:05:49
# 3       100                   1990      True  2022-12-23 13:44:41
# 4       100                  90472      True  2023-01-26 14:19:50
#
#           ResponseId  RecipientLastName  RecipientFirstName  RecipientEmail  \
# ...

# %%
ips = df[['StartDate','IPAddress']]
ips.columns = ['timestamp', 'ip_address']
ips.head()
# Out:
#              timestamp      ip_address
# 0  2022-12-06 14:06:19    24.56.247.88
# 1  2022-12-08 14:49:19     128.61.73.2
# 2  2022-12-02 21:55:51  216.110.195.70
# 3  2022-12-23 13:11:30   64.251.50.109
# 4  2023-01-25 13:11:56   128.61.19.112

# %%
ips.to_csv('qualtrics_ip.csv', index=False)
